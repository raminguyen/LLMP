# %% [markdown]
# ## Overall
#
# 1. GPT4vision struggled the most, often failing to give answers and sometimes returning errors. It frequently overestimated values, making it unreliable.
#
# 2. CustomLLaVA did well in some tasks, like measuring angles, where it got close to the correct values. However, it was inconsistent, especially with more complex tasks like measuring volume and position scale.
#
# 3. gpt4o generally performed better, often getting closer to the correct values, but it still showed some variability, especially in tasks like bar types and volumes, where it sometimes overestimate the ground truth label.
#
# 4. LLaVA often underestimated or gave erratic results, making it less accurate, particularly in tasks like bar_type1 and pie charts.
#
# 5. GeminiProVision and GPT-4 Vision's don't have ability to indicate the curvature as those returns errors messages. GeminiProVision and Gemini1_5Flash tended to overestimate, especially in tasks like angles and volumes, often giving results much higher than the correct values. Especially, Gemini1_5Flash has relative consistency, frequently offering values near the ground truth value, although with some variations.

# %%
# Import the function from the Python script
from prompt_engineer import curvature, shading_pattern, position_common_scale, position_non_aligned_scale, volume, bar, pie, bar_type1, bar_type2, bar_type3, bar_type4, bar_type5, angle, area, direction, length

# %% [markdown]
# # Angles

# %%
# Call the function to display the results and queries
angle()
# Out:
# <style type="text/css">
# #T_b3feb_row4_col0, #T_b3feb_row4_col1, #T_b3feb_row4_col2, #T_b3feb_row4_col3, #T_b3feb_row4_col4, #T_b3feb_row4_col5, #T_b3feb_row4_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b3feb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3feb_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_b3feb_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_b3feb_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_b3feb_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_b3feb_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_b3feb_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_b3feb_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3feb_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **CustomLLaVA came closest to the correct angle measurements but lacked consistency. Gemini1_5Flash and GeminiProVision consistently overestimated, while gpt4vision often returned errors.**

# %% [markdown]
# # Areas

# %%
area()
# Out:
# <style type="text/css">
# #T_51fd6_row1_col0, #T_51fd6_row1_col1, #T_51fd6_row1_col2, #T_51fd6_row1_col3, #T_51fd6_row1_col4, #T_51fd6_row1_col5, #T_51fd6_row1_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_51fd6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51fd6_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_51fd6_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_51fd6_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_51fd6_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_51fd6_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_51fd6_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_51fd6_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51fd6_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4o gave the closest estimate for Q1, but the rest of its results were inconsistent. CustomLLaVA and Gemini1_5Flash frequently overestimated, while LLaVA showed erratic values.**

# %% [markdown]
# # Curvatures

# %%
curvature()
# Out:
# <style type="text/css">
# #T_44fad_row1_col0, #T_44fad_row1_col1, #T_44fad_row1_col2, #T_44fad_row1_col3, #T_44fad_row1_col4, #T_44fad_row1_col5, #T_44fad_row1_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_44fad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44fad_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_44fad_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_44fad_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_44fad_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_44fad_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_44fad_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_44fad_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44fad_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# # Direction

# %%
direction()
# Out:
# <style type="text/css">
# #T_f0131_row2_col0, #T_f0131_row2_col1, #T_f0131_row2_col2, #T_f0131_row2_col3, #T_f0131_row2_col4, #T_f0131_row2_col5, #T_f0131_row2_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f0131">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0131_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_f0131_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_f0131_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_f0131_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_f0131_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_f0131_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_f0131_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0131_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4-vision gave two correct answers, but it returned error messages and inaccurate results. GPT-4o, LLaVA, GeminiProVision, and Gemini1_5Flash all consistently provided values far from the ground truth, with LLaVA and GeminiProVision repeatedly giving the incorrect value of 45.**

# %% [markdown]
# # Length

# %%
length()
# Out:
# <style type="text/css">
# #T_7ad8f_row1_col0, #T_7ad8f_row1_col1, #T_7ad8f_row1_col2, #T_7ad8f_row1_col3, #T_7ad8f_row1_col4, #T_7ad8f_row1_col5, #T_7ad8f_row1_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7ad8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ad8f_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_7ad8f_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_7ad8f_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_7ad8f_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_7ad8f_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_7ad8f_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_7ad8f_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ad8f_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4o was closer to the correct length of 6 in some queries but showed variability in others. LLaVA and Gemini1_5Flash greatly overestimated with values like 100, far exceeding the correct length. CustomLLaVA provided varied results, with some being much lower or higher than the ground truth.**

# %% [markdown]
# # Position_common_scale

# %%
position_common_scale()
# Out:
# <style type="text/css">
# #T_f62cf_row4_col0, #T_f62cf_row4_col1, #T_f62cf_row4_col2, #T_f62cf_row4_col3, #T_f62cf_row4_col4, #T_f62cf_row4_col5, #T_f62cf_row4_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f62cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f62cf_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_f62cf_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_f62cf_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_f62cf_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_f62cf_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_f62cf_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_f62cf_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f62cf_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4o consistently overestimated, giving values like 25 and 28 compared to the correct value of 3.LLaVA and Gemini1_5Flash also significantly overestimated, with LLaVA showing extreme values like 100, while CustomLLaVA had mixed results, sometimes getting close (e.g., 10) but often being far off the mark.**

# %% [markdown]
# # Position_non_aligned_scale

# %%
position_non_aligned_scale()
# Out:
# <style type="text/css">
# #T_c7baa_row1_col0, #T_c7baa_row1_col1, #T_c7baa_row1_col2, #T_c7baa_row1_col3, #T_c7baa_row1_col4, #T_c7baa_row1_col5, #T_c7baa_row1_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c7baa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7baa_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_c7baa_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_c7baa_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_c7baa_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_c7baa_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_c7baa_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_c7baa_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7baa_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4o provided accurate values only in q1 but frequently deviated in other queries, especially in q7 where it gave 0. LLaVA and Gemini1_5Flash consistently overestimated, with LLaVA often giving 100 and Gemini1_5Flash providing high values like 95 and 99.**

# %% [markdown]
# # Pattern

# %%
shading_pattern()
# Out:
# <style type="text/css">
# #T_61d05_row1_col0, #T_61d05_row1_col1, #T_61d05_row1_col2, #T_61d05_row1_col3, #T_61d05_row1_col4, #T_61d05_row1_col5, #T_61d05_row1_col6, #T_61d05_row6_col0, #T_61d05_row6_col1, #T_61d05_row6_col2, #T_61d05_row6_col3, #T_61d05_row6_col4, #T_61d05_row6_col5, #T_61d05_row6_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_61d05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61d05_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_61d05_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_61d05_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_61d05_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_61d05_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_61d05_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_61d05_level0_col6" class="col_heading level0 col6" >q7</th>
# ...

# %% [markdown]
# **GPT-4o often provided values close to the ground truth, like 88 in q1, but often deviated significantly, with lower estimates like 29 in q2 and q7. Gemini1_5Flash showed relative consistency, frequently offering values near the ground truth of 96, although with some variations.**

# %% [markdown]
# # Volume

# %%
volume()
# Out:
# <style type="text/css">
# #T_1e2ce_row4_col0, #T_1e2ce_row4_col1, #T_1e2ce_row4_col2, #T_1e2ce_row4_col3, #T_1e2ce_row4_col4, #T_1e2ce_row4_col5, #T_1e2ce_row4_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1e2ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e2ce_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_1e2ce_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_1e2ce_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_1e2ce_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_1e2ce_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_1e2ce_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_1e2ce_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e2ce_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4o, LLaVA, and GeminiProVision consistently provided values far from the ground truth, often vastly overestimating with figures like 1,000,000. CustomLLaVA and Gemini1_5Flash occasionally gave closer estimates but still showed significant deviations in most queries.**

# %% [markdown]
# # Bar

# %%
bar()
# Out:
#                                                                 q1  \
# GT                                       [1.0, 0.7, 0.4, 0.8, 0.3]
# gpt4o                                    [1.0, 0.8, 0.6, 0.4, 0.5]
# gpt4vision       I'm sorry, but I can't provide assistance with...
# LLaVA                                  [1.0, 0.5, 0.33, 0.25, 0.1]
# CustomLLaVA                              [1.0, 0.1, 0.7, 0.4, 0.2]
# GeminiProVision                          [1.0, 0.4, 0.6, 0.9, 0.3]
# Gemini1_5Flash                           [1.0, 0.8, 0.5, 0.3, 0.2]
#
#                                         q2                         q3  \
# GT               [1.0, 0.7, 0.4, 0.8, 0.3]  [1.0, 0.7, 0.4, 0.8, 0.3]
# gpt4o            [1.0, 0.8, 0.6, 0.4, 0.9]  [1.0, 0.8, 0.6, 0.4, 0.2]
# gpt4vision       [1.0, 0.6, 0.4, 0.5, 0.7]  [1.0, 0.8, 0.6, 0.4, 0.2]
# LLaVA            [1.0, 0.5, 0.3, 0.6, 0.7]                      [0.5]
# CustomLLaVA      [1.0, 0.5, 0.3, 0.2, 0.7]  [1.0, 0.3, 0.1, 0.6, 0.2]
# ...

# %% [markdown]
# **gpt4o, gpt4vision, and LLaVA struggled to provide values close to the ground truth, often deviating with incorrect proportions. CustomLLaVA and GeminiProVision produced results that were slightly closer but still inconsistent across different queries**

# %% [markdown]
# # Pie

# %%
pie()
# Out:
# <style type="text/css">
# #T_b4864_row1_col0, #T_b4864_row1_col1, #T_b4864_row1_col2, #T_b4864_row1_col3, #T_b4864_row1_col4, #T_b4864_row1_col5, #T_b4864_row1_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b4864">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4864_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_b4864_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_b4864_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_b4864_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_b4864_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_b4864_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_b4864_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4864_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **GPT-4o consistently provided values somewhat close to the ground truth but with slight inaccuracies, especially in ordering. gpt4vision and LLaVA struggled significantly, often deviating from the expected values, while CustomLLaVA showed the most variation, making it inconsistent across different queries**

# %% [markdown]
# # bar_type1

# %%
bar_type1()
# Out:
# <style type="text/css">
# #T_ee752_row4_col0, #T_ee752_row4_col1, #T_ee752_row4_col2, #T_ee752_row4_col3, #T_ee752_row4_col4, #T_ee752_row4_col5, #T_ee752_row4_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ee752">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee752_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_ee752_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_ee752_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_ee752_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_ee752_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_ee752_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_ee752_level0_col6" class="col_heading level0 col6" >q7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee752_level0_row0" class="row_heading level0 row0" >GT</th>
# ...

# %% [markdown]
# **All models provided values that were consistently lower than the ground truth of 0.84, with GPT-4o and LLaVA especially underestimating, while CustomLLaVA showed some close but inconsistent results.**

# %% [markdown]
# # Bar_type 2

# %%
bar_type2()
# Out:
# <style type="text/css">
# #T_2ee74_row1_col0, #T_2ee74_row1_col1, #T_2ee74_row1_col2, #T_2ee74_row1_col3, #T_2ee74_row1_col4, #T_2ee74_row1_col5, #T_2ee74_row1_col6, #T_2ee74_row2_col0, #T_2ee74_row2_col1, #T_2ee74_row2_col2, #T_2ee74_row2_col3, #T_2ee74_row2_col4, #T_2ee74_row2_col5, #T_2ee74_row2_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2ee74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ee74_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_2ee74_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_2ee74_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_2ee74_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_2ee74_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_2ee74_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_2ee74_level0_col6" class="col_heading level0 col6" >q7</th>
# ...

# %% [markdown]
# **Most models provided values slightly off from the ground truth of 0.5626. GPT-4o and GPT-4-vision were generally closer but still varied, while LLaVA and GeminiProVision consistently underestimated.**

# %% [markdown]
# # Bar_type 3

# %%
bar_type3()
# Out:
# <style type="text/css">
# #T_cf673_row1_col0, #T_cf673_row1_col1, #T_cf673_row1_col2, #T_cf673_row1_col3, #T_cf673_row1_col4, #T_cf673_row1_col5, #T_cf673_row1_col6, #T_cf673_row2_col0, #T_cf673_row2_col1, #T_cf673_row2_col2, #T_cf673_row2_col3, #T_cf673_row2_col4, #T_cf673_row2_col5, #T_cf673_row2_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cf673">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf673_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_cf673_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_cf673_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_cf673_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_cf673_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_cf673_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_cf673_level0_col6" class="col_heading level0 col6" >q7</th>
# ...

# %% [markdown]
# **GPT-4o and GPT-4-vision consistently overestimated and underestimated the correct value of 0.375, while LLaVA and GeminiProVision significantly underestimated. CustomLLaVA showed a mix of close and high estimates, lacking consistency.**

# %% [markdown]
# # Bar_type 4

# %%
bar_type4()
# Out:
# <style type="text/css">
# #T_cec88_row1_col0, #T_cec88_row1_col1, #T_cec88_row1_col2, #T_cec88_row1_col3, #T_cec88_row1_col4, #T_cec88_row1_col5, #T_cec88_row1_col6, #T_cec88_row2_col0, #T_cec88_row2_col1, #T_cec88_row2_col2, #T_cec88_row2_col3, #T_cec88_row2_col4, #T_cec88_row2_col5, #T_cec88_row2_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cec88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cec88_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_cec88_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_cec88_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_cec88_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_cec88_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_cec88_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_cec88_level0_col6" class="col_heading level0 col6" >q7</th>
# ...

# %% [markdown]
# **GPT-4o and GPT-4-vision mostly provided values close to the ground truth of 0.68, though they occasionally overestimated. LLaVA and GeminiProVision consistently underestimated, while CustomLLaVA showed variability, with both accurate and overestimated results.**

# %% [markdown]
# # Bar_type 5

# %%
bar_type5()
# Out:
# <style type="text/css">
# #T_865fd_row4_col0, #T_865fd_row4_col1, #T_865fd_row4_col2, #T_865fd_row4_col3, #T_865fd_row4_col4, #T_865fd_row4_col5, #T_865fd_row4_col6, #T_865fd_row5_col0, #T_865fd_row5_col1, #T_865fd_row5_col2, #T_865fd_row5_col3, #T_865fd_row5_col4, #T_865fd_row5_col5, #T_865fd_row5_col6 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_865fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_865fd_level0_col0" class="col_heading level0 col0" >q1</th>
#       <th id="T_865fd_level0_col1" class="col_heading level0 col1" >q2</th>
#       <th id="T_865fd_level0_col2" class="col_heading level0 col2" >q3</th>
#       <th id="T_865fd_level0_col3" class="col_heading level0 col3" >q4</th>
#       <th id="T_865fd_level0_col4" class="col_heading level0 col4" >q5</th>
#       <th id="T_865fd_level0_col5" class="col_heading level0 col5" >q6</th>
#       <th id="T_865fd_level0_col6" class="col_heading level0 col6" >q7</th>
# ...

# %% [markdown]
# **GPT-4o and GPT-4-vision tended to overestimate the correct value of 0.46, while LLaVA provided inconsistent and mostly underestimated results. CustomLLaVA showed a mix of close and overestimated values, and GeminiProVision varied between underestimation and close approximations.**
